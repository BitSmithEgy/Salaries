# %% [markdown]
# Importing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read DataFrame.

# %%
df = pd.read_csv("./Salaries.csv")
# Out:
# C:\Users\mohammed\AppData\Local\Temp\ipykernel_8984\2703893435.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Salaries.csv")

# %% [markdown]
# Get some info about DataFrame.

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# Data Preproccessing.

# %%
df.tail(30)
# Out:
#             Id            EmployeeName                      JobTitle  \
# 148624  148625      Lorraine Rosenthal                  Senior Clerk
# 148625  148626         Renato C Gurion              Registered Nurse
# 148626  148627           Paulet Gaines                 Account Clerk
# 148627  148628        Brett A Lundberg               General Laborer
# 148628  148629          Mark W Mcclure               General Laborer
# 148629  148630       Elizabeth Iniguez            Transcriber Typist
# 148630  148631            Randy J Keys                     Carpenter
# 148631  148632         Andre M Johnson   Communications Dispatcher 1
# 148632  148633  Sharon D Owens-Webster    Protective Services Worker
# 148633  148634        Edward Ferdinand               General Laborer
# 148634  148635          David M Turner           Transit Car Cleaner
# 148635  148636     James S Kibblewhite               General Laborer
# 148636  148637           Andrew J Enzi           Arborist Technician
# ...

# %%
df['BasePay'].mask(df['BasePay'] == 'Not Provided', np.nan, inplace=True)
df['TotalPay'].mask(df['TotalPay'] == 'Not Provided', np.nan, inplace=True)
df['TotalPayBenefits'].mask(df['TotalPayBenefits'] == 'Not Provided', np.nan, inplace=True)
df['OvertimePay'].mask(df['OvertimePay'] == 'Not Provided', np.nan, inplace=True)
df['OtherPay'].mask(df['OtherPay'] == 'Not Provided', np.nan, inplace=True)
df['Benefits'].mask(df['Benefits'] == 'Not Provided', np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.drop("Notes", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
#  11  Status            38119 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 13.6+ MB

# %%
df["Status"].fillna(df["Status"].mode()[0],inplace=True)

# %%
df["Status"].value_counts()
# Out:
# Status
# FT    132869
# PT     15785
# Name: count, dtype: int64

# %%
df["Status"].isna().sum()
# Out:
# 0

# %%
df[["BasePay","Benefits"]].mode()
# Out:
#   BasePay Benefits
# 0     0.0      0.0

# %%
df["BasePay"].fillna(df["BasePay"].mode()[0],inplace=True)

# %%
df["Benefits"].fillna(df["Benefits"].mode()[0],inplace=True)
df["OvertimePay"].fillna(df["OvertimePay"].mode()[0],inplace=True)
df["OtherPay"].fillna(df["OtherPay"].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# Status              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148654 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          148654 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
#  11  Status            148654 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 13.6+ MB

# %%
train_target = []
for i in df.columns:
    column = df[i]
    value = column[0]
    if type(value) == str:
        print(value)
        train_target.append(i)
        continue
# Out:
# NATHANIEL FORD
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# San Francisco
# FT

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

for i in train_target:
    le_level = LabelEncoder()
    le_level.fit(list(df[i]))
    df[i] = le_level.fit_transform(df[i])

# %% [markdown]
# Feature seliction.

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Agency', 'Status'],
#       dtype='object')

# %%
df
# Out:
#             Id  EmployeeName  JobTitle    BasePay OvertimePay   OtherPay  \
# 0            1         77059       831  167411.18         0.0  400184.25
# 1            2         34410       293  155966.02   245131.88  137811.38
# 2            3           458       293  212739.13   106088.18    16452.6
# 3            4         13984      2125    77916.0    56120.71   198306.9
# 4            5         80493       576   134401.6      9737.0  182234.59
# ...        ...           ...       ...        ...         ...        ...
# 148649  148650         91653       562       0.00        0.00       0.00
# 148650  148651         79495      1274        0.0         0.0        0.0
# 148651  148652         79495      1274        0.0         0.0        0.0
# 148652  148653         79495      1274        0.0         0.0        0.0
# 148653  148654         50065       523       0.00        0.00    -618.13
#
#        Benefits   TotalPay  TotalPayBenefits  Year  Agency  Status
# ...

# %%
X = df[['JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
       'Benefits','Year', 'Agency', 'Status']]
y = df["TotalPay"]

# %%
X.shape
# Out:
# (148654, 8)

# %%
y.shape
# Out:
# (148654,)

# %% [markdown]
# Splitting.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=101)

# %% [markdown]
# Modeling

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression().fit(x_train, y_train)

# %%
y_pred = LR.predict(x_test)

# %%
from sklearn.metrics import r2_score

acc = r2_score(y_test, y_pred)
acc
# Out:
# 1.0
